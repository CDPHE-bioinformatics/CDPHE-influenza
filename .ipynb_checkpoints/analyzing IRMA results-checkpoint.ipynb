# %% [markdown]
# # Analyzing IRMA results
#
# - In this notebook I'm going to pull down the coverage file and fasta files from IRMA that I ran in terra and then seperately calculate the percent coverage, depth etc.
# - also pull down the parameters csv
# - I'll make a sequenicng summary report
# - I'll make a horizon parser template

# %%
# load modules
import os
import glob
import re
import shutil
import pandas as pd
from datetime import date


# biopython
from Bio import SeqIO
from Bio.SeqRecord import SeqRecord

# %%
# set paths and variables
wd = '/home/molly_hetheringtonrauth/sandbox_influenza/22-23_flu_season_sequencing/'
seq_run = 'Seq320_QC_Flu'

seq_run_dir = os.path.join(wd, seq_run)
if not os.path.exists(seq_run_dir):
    os.mkdir(seq_run_dir)

# %%
# read in sample sheet to create sample list
path = '/home/molly_hetheringtonrauth/flu_sequencing/Seq320_QC_Flu/Seq320_QC_Flu_workbook.tsv'
wb = pd.read_csv(path, sep = '\t', dtype = {'hsn' : object})
sample_list = wb.sample_id.tolist()
sample_list
# Out:
# ['2103654965',
#  '2103657479',
#  '2103686192',
#  '2103694648',
#  '2103694647',
#  '2103694646',
#  '2103694645',
#  '2103695871',
#  '2103687870',
#  '2103697092',
#  '2103697094',
#  '2103697096',
#  '2103703134',
#  '2103703133',
#  '2103703136',
#  '2103703135',
#  '2103703132',
#  '2103703125',
#  '2103703126',
#  '2103703127',
#  '2103704180',
#  '2103705612',
#  '2103709477',
#  '2103709475',
#  '2103709474',
#  '2103709446',
#  '2103708187',
#  '2103708185',
#  '2103707279',
#  '2103707159',
#  '2103704199',
#  '2103710997',
#  '2103710993',
#  '2103710192',
#  '2103710190',
#  '2103710187',
#  '2103710184',
#  '2103710166',
#  '2103710163',
#  '2103704473',
#  '2103695872',
#  '2103697095',
#  '2103704187',
#  '2103704198',
#  '2103704188',
#  '2103704186',
#  'POS-A',
#  'POS-B',
#  'NTC']

# %%
# pull down files
out_dir = os.path.join(seq_run_dir, 'results')
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
    
irma_gcp_path = '{gs://path_to_workflow_outputs/irma/}'
summary_stats_gcp_path = 'gs://path_workflow_out_puts/summary_stats/'

# !gsutil -m cp -r {irma_gcp_path} {out_dir}
# !gsutil -m cp -r {summary_stats_gcp_path} {out_dir}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eb0bbc153ed0> in <module>
#       1 # pull down files
# ----> 2 out_dir = os.path.join(seq_run_dir, 'results')
#       3 if not os.path.exists(out_dir):
#       4     os.mkdir(out_dir)
#       5
#
# NameError: name 'os' is not defined

# %%
ref_len_dict = {'A_MP': 982,'A_NP': 1497,'A_NS': 863,'A_PA': 2151,'A_PB1': 2274,'A_PB2': 2280,
    'A_HA_H1': 1704,'A_HA_H10': 1686,'A_HA_H11': 1698,'A_HA_H12': 1695,'A_HA_H13': 1701,'A_HA_H14': 1707,
    'A_HA_H15': 1713,'A_HA_H16': 1698,'A_HA_H2': 1689,'A_HA_H3': 1704,'A_HA_H4': 1695,'A_HA_H5': 1707,
    'A_HA_H6': 1704,'A_HA_H7': 1713,'A_HA_H8': 1701,'A_HA_H9': 1683,'A_NA_N1': 1413,'A_NA_N2': 1410,
    'A_NA_N3': 1410,'A_NA_N4': 1413,'A_NA_N5': 1422,'A_NA_N6': 1413,'A_NA_N7': 1416,
    'A_NA_N8': 1413,'A_NA_N9': 1413,'B_HA': 1758,'B_MP': 1139,'B_NA': 1408,'B_NP': 1683,
    'B_NS': 1034,'B_PA': 2181,'B_PB1': 2263,'B_PB2': 2313}

# %%
# create df 
col_headers = ['sample_name','flu_type','subtype', 'lineage', 'clade','num_gene_segments',
    'HA_expected_len','HA_seq_len','HA_mean_depth','HA_percent_coverage',
    'NA_expected_len','NA_seq_len','NA_mean_depth','NA_percent_coverage',
    'MP_expected_len','MP_seq_len','MP_mean_depth','MP_percent_coverage',
    'NP_expected_len','NP_seq_len','NP_mean_depth','NP_percent_coverage',
    'NS_expected_len','NS_seq_len','NS_mean_depth','NS_percent_coverage',
    'PA_expected_len','PA_seq_len','PA_mean_depth','PA_percent_coverage',
    'PB1_expected_len','PB1_seq_len','PB1_mean_depth','PB1_percent_coverage',
    'PB2_expected_len','PB2_seq_len','PB2_mean_depth','PB2_percent_coverage']
df = pd.DataFrame(columns = col_headers)
df
# Out:
# Empty DataFrame
# Columns: [sample_name, flu_type, subtype, lineage, clade, num_gene_segments, HA_expected_len, HA_seq_len, HA_mean_depth, HA_percent_coverage, NA_expected_len, NA_seq_len, NA_mean_depth, NA_percent_coverage, MP_expected_len, MP_seq_len, MP_mean_depth, MP_percent_coverage, NP_expected_len, NP_seq_len, NP_mean_depth, NP_percent_coverage, NS_expected_len, NS_seq_len, NS_mean_depth, NS_percent_coverage, PA_expected_len, PA_seq_len, PA_mean_depth, PA_percent_coverage, PB1_expected_len, PB1_seq_len, PB1_mean_depth, PB1_percent_coverage, PB2_expected_len, PB2_seq_len, PB2_mean_depth, PB2_percent_coverage]
# Index: []
#
# [0 rows x 38 columns]

# %%
# for each sample, 
# type and subtype
# calc perc cov
# cacl av depth
# add in other run parameters
null_samples = []
parameters_df_list = []

for i, sample in enumerate(sample_list):
    os.chdir(seq_run_dir)
    print('**************************************')
    print(i, sample)
    df.at[i, 'sample_name'] = sample
    
    # add parameters # read in parameter file
    path = os.path.join(out_dir, 'summary_stats', '%s_parameters_and_outputs.tsv' % sample)
    para_df= pd.read_csv(path, sep = '\t', dtype = {'sample_name' : object})
    parameters_df_list.append(para_df)
    
    # read in consensus_fastas
    path = os.path.join(out_dir, 'irma', sample, 'consesnus_fastas')
    os.chdir(path)
    
    # type/subytpe
    flu_type = ''
    subtype = ''
    
    for n, fasta in enumerate(glob.glob('*.fasta')):
        file_name = fasta.split('.fasta')[0]
        
        print(n, fasta)
        if n == 0 :
            pot_flu_type = file_name.split('_')[1]
            if pot_flu_type != '*':
                flu_type = pot_flu_type
            elif pot_flu_type == '*':
                null_samples.append(sample)
                
    if flu_type == 'A':
        HA_subtype = ''
        NA_subtype = ''
        for fasta in glob.glob('*.fasta'):
            file_name = fasta.split('.fasta')[0]
            if re.search('HA', fasta):
                HA_subtype = file_name.split('_')[-1]
            elif re.search('NA', fasta):
                NA_subtype = file_name.split('_')[-1]
        subtype = '%s%s' % (HA_subtype, NA_subtype)
    
    df.at[i, 'flu_type'] = flu_type
    df.at[i, 'subtype'] = subtype
    
    if sample not in null_samples:
        # coverage
        for k, fasta in enumerate(glob.glob('*.fasta')):
            file_name = fasta.split('.fasta')[0]
            type_segment = ('_').join(file_name.split('_')[1:])
            segment = file_name.split('_')[2]
            
            print(file_name, type_segment)
            
            record = SeqIO.read(fasta, 'fasta')
            sequence_length = len(record.seq)
            expected_length = ref_len_dict[type_segment]
            per_cov = round(((sequence_length/expected_length)*100), 2)
            
            col1_name = '%s_expected_len' % segment
            col2_name = '%s_seq_len' % segment
            col3_name = '%s_percent_coverage' % segment
            
            df.at[i, col1_name] = expected_length
            df.at[i, col2_name] = sequence_length
            df.at[i, col3_name] = per_cov
            
        df.at[i, 'num_gene_segments'] = k + 1
        
        # read in coverage files
        path = os.path.join(out_dir, 'irma', sample, 'tables')
        os.chdir(path)
        for file in glob.glob('*-coverage.txt'):
            segment = file.split('-coverage.txt')[0].split('_')[2]
            cov_df = pd.read_csv(file, sep = '\t')
            cov_df = cov_df.rename(columns = {'Coverage Depth': 'coverage_depth'})
            mean_depth = cov_df.coverage_depth.mean()
            
            col_name = '%s_mean_depth' % segment
            df.at[i, col_name] = mean_depth
    else:
        df.at[i, 'num_gene_segments'] = 0
            

        
p_df = pd.concat(parameters_df_list).reset_index(drop = True)
p_df = p_df.set_index('sample_name')

df = df.set_index('sample_name')

j = df.join(p_df, how = 'left')
j = j.reset_index()
j
# Out:
# **************************************
# 0 2103654965
# 0 2103654965_A_PB2.fasta
# 1 2103654965_A_PA.fasta
# 2 2103654965_A_NA_N2.fasta
# 3 2103654965_A_HA_H3.fasta
# 4 2103654965_A_NP.fasta
# 5 2103654965_A_MP.fasta
# 6 2103654965_A_NS.fasta
# 7 2103654965_A_PB1.fasta
# 2103654965_A_PB2 A_PB2
# 2103654965_A_PA A_PA
# 2103654965_A_NA_N2 A_NA_N2
# 2103654965_A_HA_H3 A_HA_H3
# 2103654965_A_NP A_NP
# 2103654965_A_MP A_MP
# 2103654965_A_NS A_NS
# 2103654965_A_PB1 A_PB1
# **************************************
# 1 2103657479
# 0 2103657479_*.fasta
# **************************************
# 2 2103686192
# 0 2103686192_*.fasta
# **************************************
# 3 2103694648
# 0 2103694648_A_PB1.fasta
# 1 2103694648_A_NS.fasta
# 2 2103694648_A_PB2.fasta
# 3 2103694648_A_HA_H1.fasta
# 4 2103694648_A_MP.fasta
# 5 2103694648_A_PA.fasta
# 6 2103694648_A_NP.fasta
# 7 2103694648_A_NA_N1.fasta
# 2103694648_A_PB1 A_PB1
# 2103694648_A_NS A_NS
# 2103694648_A_PB2 A_PB2
# 2103694648_A_HA_H1 A_HA_H1
# 2103694648_A_MP A_MP
# 2103694648_A_PA A_PA
# 2103694648_A_NP A_NP
# 2103694648_A_NA_N1 A_NA_N1
# **************************************
# 4 2103694647
# 0 2103694647_A_NP.fasta
# 1 2103694647_A_NA_N2.fasta
# 2 2103694647_A_PB2.fasta
# 3 2103694647_A_PB1.fasta
# 4 2103694647_A_PA.fasta
# 5 2103694647_A_MP.fasta
# 6 2103694647_A_HA_H3.fasta
# 7 2103694647_A_NS.fasta
# 2103694647_A_NP A_NP
# 2103694647_A_NA_N2 A_NA_N2
# 2103694647_A_PB2 A_PB2
# 2103694647_A_PB1 A_PB1
# 2103694647_A_PA A_PA
# 2103694647_A_MP A_MP
# 2103694647_A_HA_H3 A_HA_H3
# 2103694647_A_NS A_NS
# **************************************
# 5 2103694646
# 0 2103694646_A_MP.fasta
# 1 2103694646_A_HA_H1.fasta
# 2103694646_A_MP A_MP
# 2103694646_A_HA_H1 A_HA_H1
# **************************************
# 6 2103694645
# 0 2103694645_A_NS.fasta
# 2103694645_A_NS A_NS
# **************************************
# 7 2103695871
# 0 2103695871_*.fasta
# **************************************
# 8 2103687870
# 0 2103687870_*.fasta
# **************************************
# 9 2103697092
# 0 2103697092_A_NP.fasta
# 1 2103697092_A_PB2.fasta
# 2 2103697092_A_PB1.fasta
# 3 2103697092_A_MP.fasta
# 4 2103697092_A_HA_H3.fasta
# 5 2103697092_A_NA_N2.fasta
# 6 2103697092_A_NS.fasta
# 7 2103697092_A_PA.fasta
# 2103697092_A_NP A_NP
# 2103697092_A_PB2 A_PB2
# 2103697092_A_PB1 A_PB1
# 2103697092_A_MP A_MP
# 2103697092_A_HA_H3 A_HA_H3
# 2103697092_A_NA_N2 A_NA_N2
# 2103697092_A_NS A_NS
# 2103697092_A_PA A_PA
# **************************************
# 10 2103697094
# 0 2103697094_A_PB1.fasta
# 1 2103697094_A_NA_N2.fasta
# 2 2103697094_A_NP.fasta
# 3 2103697094_A_NS.fasta
# 4 2103697094_A_PA.fasta
# 5 2103697094_A_HA_H3.fasta
# 6 2103697094_A_MP.fasta
# 7 2103697094_A_PB2.fasta
# 2103697094_A_PB1 A_PB1
# 2103697094_A_NA_N2 A_NA_N2
# 2103697094_A_NP A_NP
# 2103697094_A_NS A_NS
# 2103697094_A_PA A_PA
# 2103697094_A_HA_H3 A_HA_H3
# 2103697094_A_MP A_MP
# 2103697094_A_PB2 A_PB2
# **************************************
# 11 2103697096
# 0 2103697096_A_PB1.fasta
# 1 2103697096_A_PA.fasta
# 2 2103697096_A_NS.fasta
# 3 2103697096_A_MP.fasta
# 4 2103697096_A_NP.fasta
# 5 2103697096_A_NA_N2.fasta
# 6 2103697096_A_HA_H3.fasta
# 7 2103697096_A_PB2.fasta
# 2103697096_A_PB1 A_PB1
# 2103697096_A_PA A_PA
# 2103697096_A_NS A_NS
# 2103697096_A_MP A_MP
# 2103697096_A_NP A_NP
# 2103697096_A_NA_N2 A_NA_N2
# 2103697096_A_HA_H3 A_HA_H3
# 2103697096_A_PB2 A_PB2
# **************************************
# 12 2103703134
# 0 2103703134_A_NA_N2.fasta
# 1 2103703134_A_PA.fasta
# 2 2103703134_A_NP.fasta
# 3 2103703134_A_PB2.fasta
# 4 2103703134_A_HA_H3.fasta
# 5 2103703134_A_PB1.fasta
# 6 2103703134_A_MP.fasta
# 7 2103703134_A_NS.fasta
# 2103703134_A_NA_N2 A_NA_N2
# 2103703134_A_PA A_PA
# 2103703134_A_NP A_NP
# 2103703134_A_PB2 A_PB2
# 2103703134_A_HA_H3 A_HA_H3
# 2103703134_A_PB1 A_PB1
# 2103703134_A_MP A_MP
# 2103703134_A_NS A_NS
# **************************************
# 13 2103703133
# 0 2103703133_*.fasta
# **************************************
# 14 2103703136
# 0 2103703136_A_PB2.fasta
# 1 2103703136_A_HA_H3.fasta
# 2 2103703136_A_NP.fasta
# 3 2103703136_A_MP.fasta
# 4 2103703136_A_NA_N2.fasta
# 5 2103703136_A_NS.fasta
# 6 2103703136_A_PA.fasta
# 7 2103703136_A_PB1.fasta
# 2103703136_A_PB2 A_PB2
# 2103703136_A_HA_H3 A_HA_H3
# 2103703136_A_NP A_NP
# 2103703136_A_MP A_MP
# 2103703136_A_NA_N2 A_NA_N2
# 2103703136_A_NS A_NS
# 2103703136_A_PA A_PA
# 2103703136_A_PB1 A_PB1
# **************************************
# 15 2103703135
# 0 2103703135_A_PB2.fasta
# 1 2103703135_A_HA_H3.fasta
# 2 2103703135_A_PA.fasta
# 3 2103703135_A_NP.fasta
# 4 2103703135_A_NS.fasta
# 5 2103703135_A_MP.fasta
# 2103703135_A_PB2 A_PB2
# 2103703135_A_HA_H3 A_HA_H3
# 2103703135_A_PA A_PA
# 2103703135_A_NP A_NP
# 2103703135_A_NS A_NS
# 2103703135_A_MP A_MP
# **************************************
# 16 2103703132
# 0 2103703132_A_NS.fasta
# 1 2103703132_A_MP.fasta
# 2 2103703132_A_HA_H1.fasta
# 2103703132_A_NS A_NS
# 2103703132_A_MP A_MP
# 2103703132_A_HA_H1 A_HA_H1
# **************************************
# 17 2103703125
# 0 2103703125_A_NP.fasta
# 1 2103703125_A_PB1.fasta
# 2 2103703125_A_MP.fasta
# 3 2103703125_A_PB2.fasta
# 4 2103703125_A_NS.fasta
# 5 2103703125_A_PA.fasta
# 6 2103703125_A_HA_H3.fasta
# 7 2103703125_A_NA_N2.fasta
# 2103703125_A_NP A_NP
# 2103703125_A_PB1 A_PB1
# 2103703125_A_MP A_MP
# 2103703125_A_PB2 A_PB2
# 2103703125_A_NS A_NS
# 2103703125_A_PA A_PA
# 2103703125_A_HA_H3 A_HA_H3
# 2103703125_A_NA_N2 A_NA_N2
# **************************************
# 18 2103703126
# 0 2103703126_A_HA_H3.fasta
# 1 2103703126_A_PB2.fasta
# 2 2103703126_A_NS.fasta
# 3 2103703126_A_PB1.fasta
# 4 2103703126_A_NA_N2.fasta
# 5 2103703126_A_NP.fasta
# 6 2103703126_A_MP.fasta
# 7 2103703126_A_PA.fasta
# 2103703126_A_HA_H3 A_HA_H3
# 2103703126_A_PB2 A_PB2
# 2103703126_A_NS A_NS
# 2103703126_A_PB1 A_PB1
# 2103703126_A_NA_N2 A_NA_N2
# 2103703126_A_NP A_NP
# 2103703126_A_MP A_MP
# 2103703126_A_PA A_PA
# **************************************
# 19 2103703127
# 0 2103703127_A_NP.fasta
# 1 2103703127_A_HA_H3.fasta
# 2 2103703127_A_PA.fasta
# 3 2103703127_A_NS.fasta
# 4 2103703127_A_PB2.fasta
# 5 2103703127_A_NA_N2.fasta
# 6 2103703127_A_MP.fasta
# 7 2103703127_A_PB1.fasta
# 2103703127_A_NP A_NP
# 2103703127_A_HA_H3 A_HA_H3
# 2103703127_A_PA A_PA
# 2103703127_A_NS A_NS
# 2103703127_A_PB2 A_PB2
# 2103703127_A_NA_N2 A_NA_N2
# 2103703127_A_MP A_MP
# 2103703127_A_PB1 A_PB1
# **************************************
# 20 2103704180
# 0 2103704180_A_NP.fasta
# 1 2103704180_A_NS.fasta
# 2 2103704180_A_MP.fasta
# 3 2103704180_A_PB2.fasta
# 4 2103704180_A_PA.fasta
# 5 2103704180_A_PB1.fasta
# 6 2103704180_A_HA_H3.fasta
# 7 2103704180_A_NA_N2.fasta
# 2103704180_A_NP A_NP
# 2103704180_A_NS A_NS
# 2103704180_A_MP A_MP
# 2103704180_A_PB2 A_PB2
# 2103704180_A_PA A_PA
# 2103704180_A_PB1 A_PB1
# 2103704180_A_HA_H3 A_HA_H3
# 2103704180_A_NA_N2 A_NA_N2
# **************************************
# 21 2103705612
# 0 2103705612_A_MP.fasta
# 1 2103705612_A_HA_H1.fasta
# 2 2103705612_A_NA_N1.fasta
# 3 2103705612_A_NS.fasta
# 4 2103705612_A_PB2.fasta
# 5 2103705612_A_NP.fasta
# 6 2103705612_A_PA.fasta
# 7 2103705612_A_PB1.fasta
# 2103705612_A_MP A_MP
# 2103705612_A_HA_H1 A_HA_H1
# 2103705612_A_NA_N1 A_NA_N1
# 2103705612_A_NS A_NS
# 2103705612_A_PB2 A_PB2
# 2103705612_A_NP A_NP
# 2103705612_A_PA A_PA
# 2103705612_A_PB1 A_PB1
# **************************************
# 22 2103709477
# 0 2103709477_*.fasta
# **************************************
# 23 2103709475
# 0 2103709475_A_PA.fasta
# 1 2103709475_A_NS.fasta
# 2 2103709475_A_PB2.fasta
# 3 2103709475_A_NA_N2.fasta
# 4 2103709475_A_NP.fasta
# 5 2103709475_A_MP.fasta
# 6 2103709475_A_PB1.fasta
# 7 2103709475_A_HA_H3.fasta
# 2103709475_A_PA A_PA
# 2103709475_A_NS A_NS
# 2103709475_A_PB2 A_PB2
# 2103709475_A_NA_N2 A_NA_N2
# 2103709475_A_NP A_NP
# 2103709475_A_MP A_MP
# 2103709475_A_PB1 A_PB1
# 2103709475_A_HA_H3 A_HA_H3
# **************************************
# 24 2103709474
# 0 2103709474_A_MP.fasta
# 1 2103709474_A_NS.fasta
# 2 2103709474_A_PB1.fasta
# 3 2103709474_A_HA_H3.fasta
# 4 2103709474_A_PB2.fasta
# 5 2103709474_A_PA.fasta
# 6 2103709474_A_NA_N2.fasta
# 7 2103709474_A_NP.fasta
# 2103709474_A_MP A_MP
# 2103709474_A_NS A_NS
# 2103709474_A_PB1 A_PB1
# 2103709474_A_HA_H3 A_HA_H3
# 2103709474_A_PB2 A_PB2
# 2103709474_A_PA A_PA
# 2103709474_A_NA_N2 A_NA_N2
# 2103709474_A_NP A_NP
# **************************************
# 25 2103709446
# 0 2103709446_A_PB1.fasta
# 1 2103709446_A_NP.fasta
# 2 2103709446_A_PB2.fasta
# 3 2103709446_A_PA.fasta
# 4 2103709446_A_NS.fasta
# 5 2103709446_A_MP.fasta
# 6 2103709446_A_HA_H3.fasta
# 7 2103709446_A_NA_N2.fasta
# 2103709446_A_PB1 A_PB1
# 2103709446_A_NP A_NP
# 2103709446_A_PB2 A_PB2
# 2103709446_A_PA A_PA
# 2103709446_A_NS A_NS
# 2103709446_A_MP A_MP
# 2103709446_A_HA_H3 A_HA_H3
# 2103709446_A_NA_N2 A_NA_N2
# **************************************
# 26 2103708187
# 0 2103708187_A_HA_H3.fasta
# 1 2103708187_A_NA_N2.fasta
# 2 2103708187_A_NP.fasta
# 3 2103708187_A_MP.fasta
# 4 2103708187_A_PA.fasta
# 5 2103708187_A_PB2.fasta
# 6 2103708187_A_NS.fasta
# 7 2103708187_A_PB1.fasta
# 2103708187_A_HA_H3 A_HA_H3
# 2103708187_A_NA_N2 A_NA_N2
# 2103708187_A_NP A_NP
# 2103708187_A_MP A_MP
# 2103708187_A_PA A_PA
# 2103708187_A_PB2 A_PB2
# 2103708187_A_NS A_NS
# 2103708187_A_PB1 A_PB1
# **************************************
# 27 2103708185
# 0 2103708185_A_MP.fasta
# 1 2103708185_A_PB1.fasta
# 2 2103708185_A_NA_N2.fasta
# 3 2103708185_A_NS.fasta
# 4 2103708185_A_HA_H3.fasta
# 5 2103708185_A_PB2.fasta
# 6 2103708185_A_NP.fasta
# 7 2103708185_A_PA.fasta
# 2103708185_A_MP A_MP
# 2103708185_A_PB1 A_PB1
# 2103708185_A_NA_N2 A_NA_N2
# 2103708185_A_NS A_NS
# 2103708185_A_HA_H3 A_HA_H3
# 2103708185_A_PB2 A_PB2
# 2103708185_A_NP A_NP
# 2103708185_A_PA A_PA
# **************************************
# 28 2103707279
# 0 2103707279_A_PB2.fasta
# 2103707279_A_PB2 A_PB2
# **************************************
# 29 2103707159
# 0 2103707159_A_NA_N2.fasta
# 1 2103707159_A_NS.fasta
# 2 2103707159_A_MP.fasta
# 3 2103707159_A_HA_H3.fasta
# 4 2103707159_A_NP.fasta
# 5 2103707159_A_PB1.fasta
# 6 2103707159_A_PA.fasta
# 7 2103707159_A_PB2.fasta
# 2103707159_A_NA_N2 A_NA_N2
# 2103707159_A_NS A_NS
# 2103707159_A_MP A_MP
# 2103707159_A_HA_H3 A_HA_H3
# 2103707159_A_NP A_NP
# 2103707159_A_PB1 A_PB1
# 2103707159_A_PA A_PA
# 2103707159_A_PB2 A_PB2
# **************************************
# 30 2103704199
# 0 2103704199_*.fasta
# **************************************
# 31 2103710997
# 0 2103710997_A_NS.fasta
# 1 2103710997_A_NP.fasta
# 2 2103710997_A_HA_H3.fasta
# 3 2103710997_A_NA_N2.fasta
# 4 2103710997_A_MP.fasta
# 5 2103710997_A_PB2.fasta
# 6 2103710997_A_PA.fasta
# 7 2103710997_A_PB1.fasta
# 2103710997_A_NS A_NS
# 2103710997_A_NP A_NP
# 2103710997_A_HA_H3 A_HA_H3
# 2103710997_A_NA_N2 A_NA_N2
# 2103710997_A_MP A_MP
# 2103710997_A_PB2 A_PB2
# 2103710997_A_PA A_PA
# 2103710997_A_PB1 A_PB1
# **************************************
# 32 2103710993
# 0 2103710993_A_NP.fasta
# 1 2103710993_A_HA_H3.fasta
# 2 2103710993_A_NS.fasta
# 3 2103710993_A_NA_N2.fasta
# 4 2103710993_A_PB2.fasta
# 5 2103710993_A_PA.fasta
# 6 2103710993_A_PB1.fasta
# 7 2103710993_A_MP.fasta
# 2103710993_A_NP A_NP
# 2103710993_A_HA_H3 A_HA_H3
# 2103710993_A_NS A_NS
# 2103710993_A_NA_N2 A_NA_N2
# 2103710993_A_PB2 A_PB2
# 2103710993_A_PA A_PA
# 2103710993_A_PB1 A_PB1
# 2103710993_A_MP A_MP
# **************************************
# 33 2103710192
# 0 2103710192_A_NP.fasta
# 1 2103710192_A_MP.fasta
# 2 2103710192_A_NA_N2.fasta
# 3 2103710192_A_PB1.fasta
# 4 2103710192_A_HA_H3.fasta
# 5 2103710192_A_PB2.fasta
# 6 2103710192_A_PA.fasta
# 7 2103710192_A_NS.fasta
# 2103710192_A_NP A_NP
# 2103710192_A_MP A_MP
# 2103710192_A_NA_N2 A_NA_N2
# 2103710192_A_PB1 A_PB1
# 2103710192_A_HA_H3 A_HA_H3
# 2103710192_A_PB2 A_PB2
# 2103710192_A_PA A_PA
# 2103710192_A_NS A_NS
# **************************************
# 34 2103710190
# 0 2103710190_A_NS.fasta
# 1 2103710190_A_NA_N2.fasta
# 2 2103710190_A_MP.fasta
# 3 2103710190_A_HA_H3.fasta
# 4 2103710190_A_PB1.fasta
# 5 2103710190_A_PA.fasta
# 6 2103710190_A_NP.fasta
# 7 2103710190_A_PB2.fasta
# 2103710190_A_NS A_NS
# 2103710190_A_NA_N2 A_NA_N2
# 2103710190_A_MP A_MP
# 2103710190_A_HA_H3 A_HA_H3
# 2103710190_A_PB1 A_PB1
# 2103710190_A_PA A_PA
# 2103710190_A_NP A_NP
# 2103710190_A_PB2 A_PB2
# **************************************
# 35 2103710187
# 0 2103710187_A_PB1.fasta
# 1 2103710187_A_NS.fasta
# 2 2103710187_A_MP.fasta
# 3 2103710187_A_HA_H3.fasta
# 4 2103710187_A_PA.fasta
# 5 2103710187_A_PB2.fasta
# 6 2103710187_A_NP.fasta
# 7 2103710187_A_NA_N2.fasta
# 2103710187_A_PB1 A_PB1
# 2103710187_A_NS A_NS
# 2103710187_A_MP A_MP
# 2103710187_A_HA_H3 A_HA_H3
# 2103710187_A_PA A_PA
# 2103710187_A_PB2 A_PB2
# 2103710187_A_NP A_NP
# 2103710187_A_NA_N2 A_NA_N2
# **************************************
# 36 2103710184
# 0 2103710184_A_PB1.fasta
# 1 2103710184_A_MP.fasta
# 2 2103710184_A_PA.fasta
# 3 2103710184_A_PB2.fasta
# 4 2103710184_A_NS.fasta
# 5 2103710184_A_NP.fasta
# 6 2103710184_A_NA_N2.fasta
# 7 2103710184_A_HA_H3.fasta
# 2103710184_A_PB1 A_PB1
# 2103710184_A_MP A_MP
# 2103710184_A_PA A_PA
# 2103710184_A_PB2 A_PB2
# 2103710184_A_NS A_NS
# 2103710184_A_NP A_NP
# 2103710184_A_NA_N2 A_NA_N2
# 2103710184_A_HA_H3 A_HA_H3
# **************************************
# 37 2103710166
# 0 2103710166_A_HA_H3.fasta
# 1 2103710166_A_PB2.fasta
# 2 2103710166_A_NS.fasta
# 3 2103710166_A_NP.fasta
# 4 2103710166_A_PB1.fasta
# 5 2103710166_A_MP.fasta
# 6 2103710166_A_NA_N2.fasta
# 7 2103710166_A_PA.fasta
# 2103710166_A_HA_H3 A_HA_H3
# 2103710166_A_PB2 A_PB2
# 2103710166_A_NS A_NS
# 2103710166_A_NP A_NP
# 2103710166_A_PB1 A_PB1
# 2103710166_A_MP A_MP
# 2103710166_A_NA_N2 A_NA_N2
# 2103710166_A_PA A_PA
# **************************************
# 38 2103710163
# 0 2103710163_*.fasta
# **************************************
# 39 2103704473
# 0 2103704473_A_HA_H3.fasta
# 2103704473_A_HA_H3 A_HA_H3
# **************************************
# 40 2103695872
# 0 2103695872_B_NS.fasta
# 1 2103695872_B_PA.fasta
# 2 2103695872_B_NP.fasta
# 3 2103695872_B_NA.fasta
# 4 2103695872_B_MP.fasta
# 5 2103695872_B_HA.fasta
# 6 2103695872_B_PB1.fasta
# 7 2103695872_B_PB2.fasta
# 2103695872_B_NS B_NS
# 2103695872_B_PA B_PA
# 2103695872_B_NP B_NP
# 2103695872_B_NA B_NA
# 2103695872_B_MP B_MP
# 2103695872_B_HA B_HA
# 2103695872_B_PB1 B_PB1
# 2103695872_B_PB2 B_PB2
# **************************************
# 41 2103697095
# 0 2103697095_*.fasta
# **************************************
# 42 2103704187
# 0 2103704187_B_NS.fasta
# 2103704187_B_NS B_NS
# **************************************
# 43 2103704198
# 0 2103704198_B_PB1.fasta
# 1 2103704198_B_NP.fasta
# 2 2103704198_B_MP.fasta
# 3 2103704198_B_PB2.fasta
# 4 2103704198_B_NS.fasta
# 5 2103704198_B_PA.fasta
# 6 2103704198_B_HA.fasta
# 7 2103704198_B_NA.fasta
# 2103704198_B_PB1 B_PB1
# 2103704198_B_NP B_NP
# 2103704198_B_MP B_MP
# 2103704198_B_PB2 B_PB2
# 2103704198_B_NS B_NS
# 2103704198_B_PA B_PA
# 2103704198_B_HA B_HA
# 2103704198_B_NA B_NA
# **************************************
# 44 2103704188
# 0 2103704188_B_PB2.fasta
# 1 2103704188_B_NP.fasta
# 2 2103704188_B_HA.fasta
# 3 2103704188_B_NS.fasta
# 4 2103704188_B_NA.fasta
# 5 2103704188_B_MP.fasta
# 2103704188_B_PB2 B_PB2
# 2103704188_B_NP B_NP
# 2103704188_B_HA B_HA
# 2103704188_B_NS B_NS
# 2103704188_B_NA B_NA
# 2103704188_B_MP B_MP
# **************************************
# 45 2103704186
# 0 2103704186_B_NP.fasta
# 1 2103704186_B_MP.fasta
# 2 2103704186_B_HA.fasta
# 3 2103704186_B_PA.fasta
# 4 2103704186_B_PB2.fasta
# 5 2103704186_B_NS.fasta
# 6 2103704186_B_NA.fasta
# 2103704186_B_NP B_NP
# 2103704186_B_MP B_MP
# 2103704186_B_HA B_HA
# 2103704186_B_PA B_PA
# 2103704186_B_PB2 B_PB2
# 2103704186_B_NS B_NS
# 2103704186_B_NA B_NA
# **************************************
# 46 POS-A
# 0 POS-A_A_NA_N1.fasta
# 1 POS-A_A_PA.fasta
# 2 POS-A_A_NS.fasta
# 3 POS-A_A_PB2.fasta
# 4 POS-A_A_PB1.fasta
# 5 POS-A_A_NP.fasta
# 6 POS-A_A_MP.fasta
# 7 POS-A_A_HA_H1.fasta
# POS-A_A_NA_N1 A_NA_N1
# POS-A_A_PA A_PA
# POS-A_A_NS A_NS
# POS-A_A_PB2 A_PB2
# POS-A_A_PB1 A_PB1
# POS-A_A_NP A_NP
# POS-A_A_MP A_MP
# POS-A_A_HA_H1 A_HA_H1
# **************************************
# 47 POS-B
# 0 POS-B_B_NA.fasta
# 1 POS-B_B_PB2.fasta
# 2 POS-B_B_HA.fasta
# 3 POS-B_B_NS.fasta
# 4 POS-B_B_NP.fasta
# 5 POS-B_B_MP.fasta
# 6 POS-B_B_PB1.fasta
# POS-B_B_NA B_NA
# POS-B_B_PB2 B_PB2
# POS-B_B_HA B_HA
# POS-B_B_NS B_NS
# POS-B_B_NP B_NP
# POS-B_B_MP B_MP
# POS-B_B_PB1 B_PB1
# **************************************
# 48 NTC
# 0 NTC_*.fasta
#    sample_name flu_type subtype lineage clade num_gene_segments  \
# 0   2103654965        A    H3N2     NaN   NaN                 8
# 1   2103657479                      NaN   NaN                 0
# 2   2103686192                      NaN   NaN                 0
# 3   2103694648        A    H1N1     NaN   NaN                 8
# 4   2103694647        A    H3N2     NaN   NaN                 8
# 5   2103694646        A      H1     NaN   NaN                 2
# 6   2103694645        A             NaN   NaN                 1
# 7   2103695871                      NaN   NaN                 0
# 8   2103687870                      NaN   NaN                 0
# 9   2103697092        A    H3N2     NaN   NaN                 8
# 10  2103697094        A    H3N2     NaN   NaN                 8
# 11  2103697096        A    H3N2     NaN   NaN                 8
# 12  2103703134        A    H3N2     NaN   NaN                 8
# 13  2103703133                      NaN   NaN                 0
# 14  2103703136        A    H3N2     NaN   NaN                 8
# 15  2103703135        A      H3     NaN   NaN                 6
# 16  2103703132        A      H1     NaN   NaN                 3
# 17  2103703125        A    H3N2     NaN   NaN                 8
# 18  2103703126        A    H3N2     NaN   NaN                 8
# 19  2103703127        A    H3N2     NaN   NaN                 8
# 20  2103704180        A    H3N2     NaN   NaN                 8
# 21  2103705612        A    H1N1     NaN   NaN                 8
# 22  2103709477                      NaN   NaN                 0
# 23  2103709475        A    H3N2     NaN   NaN                 8
# 24  2103709474        A    H3N2     NaN   NaN                 8
# 25  2103709446        A    H3N2     NaN   NaN                 8
# 26  2103708187        A    H3N2     NaN   NaN                 8
# 27  2103708185        A    H3N2     NaN   NaN                 8
# 28  2103707279        A             NaN   NaN                 1
# 29  2103707159        A    H3N2     NaN   NaN                 8
# 30  2103704199                      NaN   NaN                 0
# 31  2103710997        A    H3N2     NaN   NaN                 8
# 32  2103710993        A    H3N2     NaN   NaN                 8
# 33  2103710192        A    H3N2     NaN   NaN                 8
# 34  2103710190        A    H3N2     NaN   NaN                 8
# 35  2103710187        A    H3N2     NaN   NaN                 8
# 36  2103710184        A    H3N2     NaN   NaN                 8
# 37  2103710166        A    H3N2     NaN   NaN                 8
# 38  2103710163                      NaN   NaN                 0
# 39  2103704473        A      H3     NaN   NaN                 1
# 40  2103695872        B             NaN   NaN                 8
# 41  2103697095                      NaN   NaN                 0
# 42  2103704187        B             NaN   NaN                 1
# 43  2103704198        B             NaN   NaN                 8
# 44  2103704188        B             NaN   NaN                 6
# 45  2103704186        B             NaN   NaN                 7
# 46       POS-A        A    H1N1     NaN   NaN                 8
# 47       POS-B        B             NaN   NaN                 7
# 48         NTC                      NaN   NaN                 0
#
#    HA_expected_len HA_seq_len HA_mean_depth HA_percent_coverage  ...  \
# 0             1704       1701   1343.687831               99.82  ...
# 1              NaN        NaN           NaN                 NaN  ...
# 2              NaN        NaN           NaN                 NaN  ...
# 3             1704       1701   2592.347443               99.82  ...
# 4             1704       1701    288.786596               99.82  ...
# 5             1704       1345      2.057993               78.93  ...
# 6              NaN        NaN           NaN                 NaN  ...
# 7              NaN        NaN           NaN                 NaN  ...
# 8              NaN        NaN           NaN                 NaN  ...
# 9             1704       1701   3838.238683               99.82  ...
# 10            1704       1701    127.504409               99.82  ...
# 11            1704       1701   2075.347443               99.82  ...
# 12            1704       1701   2275.085832               99.82  ...
# 13             NaN        NaN           NaN                 NaN  ...
# 14            1704       1701    3133.13933               99.82  ...
# 15            1704       1701     15.756026               99.82  ...
# 16            1704       1444      2.358033               84.74  ...
# 17            1704       1701     77.137566               99.82  ...
# 18            1704       1701    138.639624               99.82  ...
# 19            1704       1701    651.288066               99.82  ...
# 20            1704       1701   3001.845385               99.82  ...
# 21            1704       1701   2676.238095               99.82  ...
# 22             NaN        NaN           NaN                 NaN  ...
# 23            1704       1701     45.673133               99.82  ...
# 24            1704       1701     263.38448               99.82  ...
# 25            1704       1701    985.333921               99.82  ...
# 26            1704       1701     28.848325               99.82  ...
# 27            1704       1701   1539.422105               99.82  ...
# 28             NaN        NaN           NaN                 NaN  ...
# 29            1704       1656      8.874396               97.18  ...
# 30             NaN        NaN           NaN                 NaN  ...
# 31            1704       1701    683.477366               99.82  ...
# 32            1704       1701     80.453851               99.82  ...
# 33            1704       1701     11.248677               99.82  ...
# 34            1704       1701   2457.158142               99.82  ...
# 35            1704       1701    428.085244               99.82  ...
# 36            1704       1701   1816.025279               99.82  ...
# 37            1704       1701    150.922399               99.82  ...
# 38             NaN        NaN           NaN                 NaN  ...
# 39            1704       1669       3.05692               97.95  ...
# 40            1758       1739    248.595745               98.92  ...
# 41             NaN        NaN           NaN                 NaN  ...
# 42             NaN        NaN           NaN                 NaN  ...
# 43            1758       1749     23.939966               99.49  ...
# 44            1758       1703      3.260716               96.87  ...
# 45            1758       1518      7.624506               86.35  ...
# 46            1704       1701   2276.628454               99.82  ...
# 47            1758        757       6.39498               43.06  ...
# 48             NaN        NaN           NaN                 NaN  ...
#
#    total_reads_R1_raw total_reads_R2_raw read_length_R1_raw  \
# 0              123346             123346                NaN
# 1               32914              32914                NaN
# 2                 610                610                NaN
# 3              283380             283380                NaN
# 4               55996              55996                NaN
# 5               46545              46545                NaN
# 6               59352              59352                NaN
# 7               30310              30310                NaN
# 8                5491               5491                NaN
# 9              415476             415476                NaN
# 10              23898              23898                NaN
# 11             271017             271017                NaN
# 12             323551             323551                NaN
# 13                405                405                NaN
# 14             198313             198313                NaN
# 15              15100              15100                NaN
# 16                556                556                NaN
# 17               9104               9104                NaN
# 18              31467              31467                NaN
# 19             298230             298230                NaN
# 20             323347             323347                NaN
# 21             311021             311021                NaN
# 22              16897              16897                NaN
# 23              25896              25896                NaN
# 24             117151             117151                NaN
# 25             253719             253719                NaN
# 26              30831              30831                NaN
# 27             296754             296754                NaN
# 28                496                496                NaN
# 29               8958               8958                NaN
# 30                990                990                NaN
# 31             230555             230555                NaN
# 32              23286              23286                NaN
# 33              76605              76605                NaN
# 34             290255             290255                NaN
# 35             193766             193766                NaN
# 36             259169             259169                NaN
# 37              32648              32648                NaN
# 38                234                234                NaN
# 39               1082               1082                NaN
# 40             277960             277960                NaN
# 41               8750               8750                NaN
# 42              19399              19399                NaN
# 43             132817             132817                NaN
# 44              72491              72491                NaN
# 45             151309             151309                NaN
# 46             310532             310532                NaN
# 47              33767              33767                NaN
# 48                495                495                NaN
#
#    read_length_R2_raw read_pairs_raw total_reads_R1_cleaned  \
# 0              35-251         123346                  88047
# 1              35-251          32914                  23459
# 2              35-251            610                    372
# 3              35-251         283380                 214488
# 4              35-251          55996                  39438
# 5              35-251          46545                  31921
# 6              35-251          59352                  39111
# 7              35-251          30310                  19746
# 8              35-251           5491                   3359
# 9              35-251         415476                 321646
# 10             35-251          23898                  16720
# 11             35-251         271017                 203974
# 12             35-251         323551                 247951
# 13             35-251            405                    220
# 14             35-251         198313                 142852
# 15             35-251          15100                  10210
# 16             35-251            556                    364
# 17             35-251           9104                   5880
# 18             35-251          31467                  21867
# 19             35-251         298230                 220591
# 20             35-251         323347                 248262
# 21             35-251         311021                 235861
# 22             35-251          16897                  11385
# 23             35-251          25896                  17044
# 24             35-251         117151                  84351
# 25             35-251         253719                 182215
# 26             35-251          30831                  20599
# 27             35-251         296754                 225618
# 28             35-251            496                    307
# 29             35-251           8958                   5546
# 30             35-251            990                    604
# 31             35-251         230555                 168943
# 32             35-251          23286                  15843
# 33             35-251          76605                  54259
# 34             35-251         290255                 214118
# 35             35-251         193766                 134234
# 36             35-251         259169                 192386
# 37             35-251          32648                  23092
# 38             35-251            234                    140
# 39             35-251           1082                    608
# 40             35-251         277960                 207285
# 41             35-251           8750                   5705
# 42             35-251          19399                  12304
# 43             35-251         132817                  92310
# 44             35-251          72491                  49023
# 45             35-251         151309                 101285
# 46             35-251         310532                 229162
# 47             35-251          33767                  22600
# 48             35-251            495                    169
#
#    total_reads_R2_cleaned read_length_R1_cleaned read_length_R2_cleaned  \
# 0                   88047                    NaN                 70-250
# 1                   23459                    NaN                 70-250
# 2                     372                    NaN                 70-250
# 3                  214488                    NaN                 70-250
# 4                   39438                    NaN                 70-250
# 5                   31921                    NaN                 70-250
# 6                   39111                    NaN                 70-250
# 7                   19746                    NaN                 70-250
# 8                    3359                    NaN                 70-250
# 9                  321646                    NaN                 70-250
# 10                  16720                    NaN                 70-250
# 11                 203974                    NaN                 70-250
# 12                 247951                    NaN                 70-250
# 13                    220                    NaN                 70-250
# 14                 142852                    NaN                 70-250
# 15                  10210                    NaN                 70-250
# 16                    364                    NaN                 70-250
# 17                   5880                    NaN                 70-250
# 18                  21867                    NaN                 70-250
# 19                 220591                    NaN                 70-250
# 20                 248262                    NaN                 70-250
# 21                 235861                    NaN                 70-250
# 22                  11385                    NaN                 70-250
# 23                  17044                    NaN                 70-250
# 24                  84351                    NaN                 70-250
# 25                 182215                    NaN                 70-250
# 26                  20599                    NaN                 70-250
# 27                 225618                    NaN                 70-250
# 28                    307                    NaN                 70-250
# 29                   5546                    NaN                 70-250
# 30                    604                    NaN                 70-250
# 31                 168943                    NaN                 70-250
# 32                  15843                    NaN                 70-250
# 33                  54259                    NaN                 70-250
# 34                 214118                    NaN                 70-250
# 35                 134234                    NaN                 70-250
# 36                 192386                    NaN                 70-250
# 37                  23092                    NaN                 70-250
# 38                    140                    NaN                 71-250
# 39                    608                    NaN                 70-250
# 40                 207285                    NaN                 70-250
# 41                   5705                    NaN                 70-250
# 42                  12304                    NaN                 70-250
# 43                  92310                    NaN                 70-250
# 44                  49023                    NaN                 70-250
# 45                 101285                    NaN                 70-250
# 46                 229162                    NaN                 70-250
# 47                  22600                    NaN                 70-250
# 48                    169                    NaN                 70-250
#
#    read_pairs_cleaned
# 0               88047
# 1               23459
# 2                 372
# 3              214488
# 4               39438
# 5               31921
# 6               39111
# 7               19746
# 8                3359
# 9              321646
# 10              16720
# 11             203974
# 12             247951
# 13                220
# 14             142852
# 15              10210
# 16                364
# 17               5880
# 18              21867
# 19             220591
# 20             248262
# 21             235861
# 22              11385
# 23              17044
# 24              84351
# 25             182215
# 26              20599
# 27             225618
# 28                307
# 29               5546
# 30                604
# 31             168943
# 32              15843
# 33              54259
# 34             214118
# 35             134234
# 36             192386
# 37              23092
# 38                140
# 39                608
# 40             207285
# 41               5705
# 42              12304
# 43              92310
# 44              49023
# 45             101285
# 46             229162
# 47              22600
# 48                169
#
# [49 rows x 53 columns]

# %%
outfile = os.path.join(seq_run_dir, '%s_sequencing_results_full.tsv' % seq_run)
j.to_csv(outfile, index = False, sep = '\t')

# %%
col_order = ['sample_name','num_gene_segments','flu_type','subtype', 'lineage', 'clade',
    'HA_percent_coverage', 'NA_percent_coverage', 'MP_percent_coverage',
    'NP_percent_coverage', 'NS_percent_coverage', 'PA_percent_coverage',
    'PB1_percent_coverage', 'PB2_percent_coverage',
    'HA_mean_depth', 'NA_mean_depth', 'MP_mean_depth',
    'NP_mean_depth', 'NS_mean_depth', 'PA_mean_depth',
    'PB1_mean_depth', 'PB2_mean_depth',
    'HA_seq_len', 'NA_seq_len', 'MP_seq_len',
    'NP_seq_len', 'NS_seq_len', 'PA_seq_len',
    'PB1_seq_len', 'PB2_seq_len',
    'total_reads_R1_raw', 'total_reads_R2_raw', 'read_length_R1_raw', 'read_length_R2_raw', 'read_pairs_raw',
    'total_reads_R1_cleaned', 'total_reads_R2_cleaned', 'read_length_R1_cleaned', 'read_length_R2_cleaned','read_pairs_cleaned',
    'fastqc_version', 'fastqc_docker', 'seqyclean_version', 'seqyclean_docker', 'irma_version']
j2 = j[col_order]
j2
# Out:
#    sample_name num_gene_segments flu_type subtype lineage clade  \
# 0   2103654965                 8        A    H3N2     NaN   NaN
# 1   2103657479                 0                      NaN   NaN
# 2   2103686192                 0                      NaN   NaN
# 3   2103694648                 8        A    H1N1     NaN   NaN
# 4   2103694647                 8        A    H3N2     NaN   NaN
# 5   2103694646                 2        A      H1     NaN   NaN
# 6   2103694645                 1        A             NaN   NaN
# 7   2103695871                 0                      NaN   NaN
# 8   2103687870                 0                      NaN   NaN
# 9   2103697092                 8        A    H3N2     NaN   NaN
# 10  2103697094                 8        A    H3N2     NaN   NaN
# 11  2103697096                 8        A    H3N2     NaN   NaN
# 12  2103703134                 8        A    H3N2     NaN   NaN
# 13  2103703133                 0                      NaN   NaN
# 14  2103703136                 8        A    H3N2     NaN   NaN
# 15  2103703135                 6        A      H3     NaN   NaN
# 16  2103703132                 3        A      H1     NaN   NaN
# 17  2103703125                 8        A    H3N2     NaN   NaN
# 18  2103703126                 8        A    H3N2     NaN   NaN
# 19  2103703127                 8        A    H3N2     NaN   NaN
# 20  2103704180                 8        A    H3N2     NaN   NaN
# 21  2103705612                 8        A    H1N1     NaN   NaN
# 22  2103709477                 0                      NaN   NaN
# 23  2103709475                 8        A    H3N2     NaN   NaN
# 24  2103709474                 8        A    H3N2     NaN   NaN
# 25  2103709446                 8        A    H3N2     NaN   NaN
# 26  2103708187                 8        A    H3N2     NaN   NaN
# 27  2103708185                 8        A    H3N2     NaN   NaN
# 28  2103707279                 1        A             NaN   NaN
# 29  2103707159                 8        A    H3N2     NaN   NaN
# 30  2103704199                 0                      NaN   NaN
# 31  2103710997                 8        A    H3N2     NaN   NaN
# 32  2103710993                 8        A    H3N2     NaN   NaN
# 33  2103710192                 8        A    H3N2     NaN   NaN
# 34  2103710190                 8        A    H3N2     NaN   NaN
# 35  2103710187                 8        A    H3N2     NaN   NaN
# 36  2103710184                 8        A    H3N2     NaN   NaN
# 37  2103710166                 8        A    H3N2     NaN   NaN
# 38  2103710163                 0                      NaN   NaN
# 39  2103704473                 1        A      H3     NaN   NaN
# 40  2103695872                 8        B             NaN   NaN
# 41  2103697095                 0                      NaN   NaN
# 42  2103704187                 1        B             NaN   NaN
# 43  2103704198                 8        B             NaN   NaN
# 44  2103704188                 6        B             NaN   NaN
# 45  2103704186                 7        B             NaN   NaN
# 46       POS-A                 8        A    H1N1     NaN   NaN
# 47       POS-B                 7        B             NaN   NaN
# 48         NTC                 0                      NaN   NaN
#
#    HA_percent_coverage NA_percent_coverage MP_percent_coverage  \
# 0                99.82               100.0               100.0
# 1                  NaN                 NaN                 NaN
# 2                  NaN                 NaN                 NaN
# 3                99.82               99.79               100.0
# 4                99.82               100.0               100.0
# 5                78.93                 NaN               99.69
# 6                  NaN                 NaN                 NaN
# 7                  NaN                 NaN                 NaN
# 8                  NaN                 NaN                 NaN
# 9                99.82               100.0               100.0
# 10               99.82               100.0               100.0
# 11               99.82               100.0               100.0
# 12               99.82              100.21               100.0
# 13                 NaN                 NaN                 NaN
# 14               99.82               100.0               100.0
# 15               99.82                 NaN               100.0
# 16               84.74                 NaN               99.19
# 17               99.82               100.0               100.0
# 18               99.82               100.0               100.0
# 19               99.82               100.0               100.0
# 20               99.82              100.21               100.0
# 21               99.82               99.79               100.0
# 22                 NaN                 NaN                 NaN
# 23               99.82               100.0               100.0
# 24               99.82               100.0               100.0
# 25               99.82               100.0               100.0
# 26               99.82               100.0               100.0
# 27               99.82               100.0               100.0
# 28                 NaN                 NaN                 NaN
# 29               97.18               53.83               100.0
# 30                 NaN                 NaN                 NaN
# 31               99.82               100.0               100.0
# 32               99.82               100.0               100.0
# 33               99.82              101.13               100.0
# 34               99.82               100.0               100.0
# 35               99.82              100.21               100.0
# 36               99.82              100.21               100.0
# 37               99.82               100.0               100.0
# 38                 NaN                 NaN                 NaN
# 39               97.95                 NaN                 NaN
# 40               98.92               100.0               94.47
# 41                 NaN                 NaN                 NaN
# 42                 NaN                 NaN                 NaN
# 43               99.49               99.36               94.47
# 44               96.87               53.55               94.47
# 45               86.35               80.47               94.47
# 46               99.82               99.79               100.0
# 47               43.06               55.11               94.47
# 48                 NaN                 NaN                 NaN
#
#    NP_percent_coverage  ... total_reads_R1_cleaned total_reads_R2_cleaned  \
# 0                100.0  ...                  88047                  88047
# 1                  NaN  ...                  23459                  23459
# 2                  NaN  ...                    372                    372
# 3                100.0  ...                 214488                 214488
# 4                100.0  ...                  39438                  39438
# 5                  NaN  ...                  31921                  31921
# 6                  NaN  ...                  39111                  39111
# 7                  NaN  ...                  19746                  19746
# 8                  NaN  ...                   3359                   3359
# 9                100.0  ...                 321646                 321646
# 10               100.0  ...                  16720                  16720
# 11               100.0  ...                 203974                 203974
# 12               100.0  ...                 247951                 247951
# 13                 NaN  ...                    220                    220
# 14               100.0  ...                 142852                 142852
# 15               100.0  ...                  10210                  10210
# 16                 NaN  ...                    364                    364
# 17               100.0  ...                   5880                   5880
# 18               100.0  ...                  21867                  21867
# 19               100.0  ...                 220591                 220591
# 20               100.0  ...                 248262                 248262
# 21               100.0  ...                 235861                 235861
# 22                 NaN  ...                  11385                  11385
# 23               100.0  ...                  17044                  17044
# 24               100.0  ...                  84351                  84351
# 25               100.0  ...                 182215                 182215
# 26               100.0  ...                  20599                  20599
# 27               100.0  ...                 225618                 225618
# 28                 NaN  ...                    307                    307
# 29                84.3  ...                   5546                   5546
# 30                 NaN  ...                    604                    604
# 31               100.0  ...                 168943                 168943
# 32               100.0  ...                  15843                  15843
# 33               100.0  ...                  54259                  54259
# 34               100.0  ...                 214118                 214118
# 35               100.0  ...                 134234                 134234
# 36               100.0  ...                 192386                 192386
# 37               100.0  ...                  23092                  23092
# 38                 NaN  ...                    140                    140
# 39                 NaN  ...                    608                    608
# 40               98.22  ...                 207285                 207285
# 41                 NaN  ...                   5705                   5705
# 42                 NaN  ...                  12304                  12304
# 43               95.13  ...                  92310                  92310
# 44               43.55  ...                  49023                  49023
# 45               90.67  ...                 101285                 101285
# 46               100.0  ...                 229162                 229162
# 47               51.87  ...                  22600                  22600
# 48                 NaN  ...                    169                    169
#
#    read_length_R1_cleaned read_length_R2_cleaned read_pairs_cleaned  \
# 0                     NaN                 70-250              88047
# 1                     NaN                 70-250              23459
# 2                     NaN                 70-250                372
# 3                     NaN                 70-250             214488
# 4                     NaN                 70-250              39438
# 5                     NaN                 70-250              31921
# 6                     NaN                 70-250              39111
# 7                     NaN                 70-250              19746
# 8                     NaN                 70-250               3359
# 9                     NaN                 70-250             321646
# 10                    NaN                 70-250              16720
# 11                    NaN                 70-250             203974
# 12                    NaN                 70-250             247951
# 13                    NaN                 70-250                220
# 14                    NaN                 70-250             142852
# 15                    NaN                 70-250              10210
# 16                    NaN                 70-250                364
# 17                    NaN                 70-250               5880
# 18                    NaN                 70-250              21867
# 19                    NaN                 70-250             220591
# 20                    NaN                 70-250             248262
# 21                    NaN                 70-250             235861
# 22                    NaN                 70-250              11385
# 23                    NaN                 70-250              17044
# 24                    NaN                 70-250              84351
# 25                    NaN                 70-250             182215
# 26                    NaN                 70-250              20599
# 27                    NaN                 70-250             225618
# 28                    NaN                 70-250                307
# 29                    NaN                 70-250               5546
# 30                    NaN                 70-250                604
# 31                    NaN                 70-250             168943
# 32                    NaN                 70-250              15843
# 33                    NaN                 70-250              54259
# 34                    NaN                 70-250             214118
# 35                    NaN                 70-250             134234
# 36                    NaN                 70-250             192386
# 37                    NaN                 70-250              23092
# 38                    NaN                 71-250                140
# 39                    NaN                 70-250                608
# 40                    NaN                 70-250             207285
# 41                    NaN                 70-250               5705
# 42                    NaN                 70-250              12304
# 43                    NaN                 70-250              92310
# 44                    NaN                 70-250              49023
# 45                    NaN                 70-250             101285
# 46                    NaN                 70-250             229162
# 47                    NaN                 70-250              22600
# 48                    NaN                 70-250                169
#
#     fastqc_version         fastqc_docker seqyclean_version  \
# 0   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 1   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 2   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 3   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 4   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 5   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 6   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 7   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 8   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 9   FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 10  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 11  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 12  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 13  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 14  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 15  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 16  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 17  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 18  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 19  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 20  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 21  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 22  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 23  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 24  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 25  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 26  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 27  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 28  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 29  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 30  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 31  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 32  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 33  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 34  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 35  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 36  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 37  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 38  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 39  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 40  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 41  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 42  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 43  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 44  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 45  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 46  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 47  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
# 48  FastQC v0.11.9  staphb/fastqc:0.11.9           1.10.09
#
#             seqyclean_docker irma_version
# 0   staphb/seqyclean:1.10.09       v1.0.3
# 1   staphb/seqyclean:1.10.09       v1.0.3
# 2   staphb/seqyclean:1.10.09       v1.0.3
# 3   staphb/seqyclean:1.10.09       v1.0.3
# 4   staphb/seqyclean:1.10.09       v1.0.3
# 5   staphb/seqyclean:1.10.09       v1.0.3
# 6   staphb/seqyclean:1.10.09       v1.0.3
# 7   staphb/seqyclean:1.10.09       v1.0.3
# 8   staphb/seqyclean:1.10.09       v1.0.3
# 9   staphb/seqyclean:1.10.09       v1.0.3
# 10  staphb/seqyclean:1.10.09       v1.0.3
# 11  staphb/seqyclean:1.10.09       v1.0.3
# 12  staphb/seqyclean:1.10.09       v1.0.3
# 13  staphb/seqyclean:1.10.09       v1.0.3
# 14  staphb/seqyclean:1.10.09       v1.0.3
# 15  staphb/seqyclean:1.10.09       v1.0.3
# 16  staphb/seqyclean:1.10.09       v1.0.3
# 17  staphb/seqyclean:1.10.09       v1.0.3
# 18  staphb/seqyclean:1.10.09       v1.0.3
# 19  staphb/seqyclean:1.10.09       v1.0.3
# 20  staphb/seqyclean:1.10.09       v1.0.3
# 21  staphb/seqyclean:1.10.09       v1.0.3
# 22  staphb/seqyclean:1.10.09       v1.0.3
# 23  staphb/seqyclean:1.10.09       v1.0.3
# 24  staphb/seqyclean:1.10.09       v1.0.3
# 25  staphb/seqyclean:1.10.09       v1.0.3
# 26  staphb/seqyclean:1.10.09       v1.0.3
# 27  staphb/seqyclean:1.10.09       v1.0.3
# 28  staphb/seqyclean:1.10.09       v1.0.3
# 29  staphb/seqyclean:1.10.09       v1.0.3
# 30  staphb/seqyclean:1.10.09       v1.0.3
# 31  staphb/seqyclean:1.10.09       v1.0.3
# 32  staphb/seqyclean:1.10.09       v1.0.3
# 33  staphb/seqyclean:1.10.09       v1.0.3
# 34  staphb/seqyclean:1.10.09       v1.0.3
# 35  staphb/seqyclean:1.10.09       v1.0.3
# 36  staphb/seqyclean:1.10.09       v1.0.3
# 37  staphb/seqyclean:1.10.09       v1.0.3
# 38  staphb/seqyclean:1.10.09       v1.0.3
# 39  staphb/seqyclean:1.10.09       v1.0.3
# 40  staphb/seqyclean:1.10.09       v1.0.3
# 41  staphb/seqyclean:1.10.09       v1.0.3
# 42  staphb/seqyclean:1.10.09       v1.0.3
# 43  staphb/seqyclean:1.10.09       v1.0.3
# 44  staphb/seqyclean:1.10.09       v1.0.3
# 45  staphb/seqyclean:1.10.09       v1.0.3
# 46  staphb/seqyclean:1.10.09       v1.0.3
# 47  staphb/seqyclean:1.10.09       v1.0.3
# 48  staphb/seqyclean:1.10.09       v1.0.3
#
# [49 rows x 45 columns]

# %%
outfile = os.path.join(seq_run_dir, '%s_sequencing_results.tsv' % seq_run)
j2.to_csv(outfile, index = False, sep = '\t')
